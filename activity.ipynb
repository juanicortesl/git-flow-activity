# %%
import pandas as pd
import json
raw_tweets = pd.read_json(r'farmers-protest-tweets-2021-03-5.json', lines=True, nrows=100000)
print("Shape: ", raw_tweets.shape)
raw_tweets.head(5)
# Out:
# Shape:  (100000, 21)
#                                                  url  \
# 0  https://twitter.com/ShashiRajbhar6/status/1376...
# 1  https://twitter.com/kaursuk06272818/status/137...
# 2  https://twitter.com/kaursuk06272818/status/137...
# 3  https://twitter.com/SukhdevSingh_/status/13767...
# 4  https://twitter.com/Davidmu66668113/status/137...
#
#                        date  \
# 0 2021-03-30 03:33:46+00:00
# 1 2021-03-30 03:33:23+00:00
# 2 2021-03-30 03:31:00+00:00
# 3 2021-03-30 03:30:45+00:00
# 4 2021-03-30 03:30:30+00:00
#
#                                              content  \
# 0                       Support 👇\n\n#FarmersProtest
# 1  Supporting farmers means supporting our countr...
# 2  Support farmers if you are related to food #St...
# 3  #StopHateAgainstFarmers support #FarmersProtes...
# 4  You hate farmers I hate you, \nif you love the...
#
#                                      renderedContent                   id  \
# 0                       Support 👇\n\n#FarmersProtest  1376739399593910273
# 1  Supporting farmers means supporting our countr...  1376739306287427584
# 2  Support farmers if you are related to food #St...  1376738704128020488
# 3  #StopHateAgainstFarmers support #FarmersProtes...  1376738640542400518
# 4  You hate farmers I hate you, \nif you love the...  1376738579171344386
#
#                                                 user outlinks tcooutlinks  \
# 0  {'username': 'ShashiRajbhar6', 'displayname': ...       []          []
# 1  {'username': 'kaursuk06272818', 'displayname':...       []          []
# 2  {'username': 'kaursuk06272818', 'displayname':...       []          []
# 3  {'username': 'SukhdevSingh_', 'displayname': '...       []          []
# 4  {'username': 'Davidmu66668113', 'displayname':...       []          []
#
#    replyCount  retweetCount  ...  quoteCount       conversationId  lang  \
# 0           0             0  ...           0  1376739399593910273    en
# 1           0             0  ...           0  1376739306287427584    en
# 2           0             0  ...           0  1376738704128020488    en
# 3           0             1  ...           0  1376738640542400518    en
# 4           0             0  ...           0  1376738579171344386    en
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/android" ...
#
#                              sourceUrl          sourceLabel  \
# 0  http://twitter.com/download/android  Twitter for Android
# 1  http://twitter.com/download/android  Twitter for Android
# 2  http://twitter.com/download/android  Twitter for Android
# 3  http://twitter.com/download/android  Twitter for Android
# 4  http://twitter.com/download/android  Twitter for Android
#
#                                                media retweetedTweet  \
# 0                                               None            NaN
# 1  [{'previewUrl': 'https://pbs.twimg.com/media/E...            NaN
# 2  [{'previewUrl': 'https://pbs.twimg.com/media/E...            NaN
# 3                                               None            NaN
# 4                                               None            NaN
#
#    quotedTweet mentionedUsers
# 0         None           None
# 1         None           None
# 2         None           None
# 3         None           None
# 4         None           None
#
# [5 rows x 21 columns]

# %%
def getTopTenRetweeted():
    topTen = raw_tweets.sort_values(by="retweetCount", ascending=False)
    topTen = topTen.iloc[:10]
    return topTen
 

topTen = getTopTenRetweeted()
topTen.head(10)
# Out:
#                                                      url  \
# 95467  https://twitter.com/dhruv_rathee/status/136414...
# 55083  https://twitter.com/TanDhesi/status/1368994520...
# 29485  https://twitter.com/sushant_says/status/137259...
# 65334  https://twitter.com/simran/status/136768101473...
# 41084  https://twitter.com/MeghUpdates/status/1371017...
# 59355  https://twitter.com/cjwerleman/status/13683355...
# 44654  https://twitter.com/J4SHANBAINS/status/1370526...
# 64307  https://twitter.com/RaviSinghKA/status/1367752...
# 29582  https://twitter.com/saahilmenghani/status/1372...
# 52660  https://twitter.com/TanDhesi/status/1369299734...
#
#                            date  \
# 95467 2021-02-23 09:40:21+00:00
# 55083 2021-03-08 18:38:22+00:00
# 29485 2021-03-18 16:52:08+00:00
# 65334 2021-03-05 03:38:58+00:00
# 41084 2021-03-14 08:37:49+00:00
# 59355 2021-03-06 22:59:48+00:00
# 44654 2021-03-13 00:04:20+00:00
# 64307 2021-03-05 08:24:46+00:00
# 29582 2021-03-18 15:29:30+00:00
# 52660 2021-03-09 14:51:11+00:00
#
#                                                  content  \
# 95467  There's a #FarmersProtest happening in Germany...
# 55083  Human rights, press and academic freedoms have...
# 29485  I am back #FarmersProtest #FreeAllPoliticalPri...
# 65334  The cover of TIME Magazine’s international edi...
# 41084  Rakesh Tikait's Rally in Nandigram reportedly ...
# 59355  Hindu nationalists (terrorists) attacked three...
# 44654  Revolution is a universal language.\n\n#Farmer...
# 64307  Wow ✊🏽✊🏽🚜🚜⁣\n⁣\nWomen farmers make the front c...
# 29582  112 days, #300DeathsAtProtest.\n\n#GodiMedia i...
# 52660  Farcical way some Indian actors and cricketers...
#
#                                          renderedContent                   id  \
# 95467  There's a #FarmersProtest happening in Germany...  1364148079117615105
# 55083  Human rights, press and academic freedoms have...  1368994520004780034
# 29485  I am back #FarmersProtest #FreeAllPoliticalPri...  1372591661490917377
# 65334  The cover of TIME Magazine’s international edi...  1367681014739460098
# 41084  Rakesh Tikait's Rally in Nandigram reportedly ...  1371017710700617729
# 59355  Hindu nationalists (terrorists) attacked three...  1368335535786184705
# 44654  Revolution is a universal language.\n\n#Farmer...  1370526101739511810
# 64307  Wow ✊🏽✊🏽🚜🚜⁣\n⁣\nWomen farmers make the front c...  1367752937808818177
# 29582  112 days, #300DeathsAtProtest.\n\n#GodiMedia i...  1372570866404397059
# 52660  Farcical way some Indian actors and cricketers...  1369299734448508928
#
#                                                     user outlinks tcooutlinks  \
# 95467  {'username': 'dhruv_rathee', 'displayname': 'D...       []          []
# 55083  {'username': 'TanDhesi', 'displayname': 'Tanma...       []          []
# 29485  {'username': 'sushant_says', 'displayname': 'स...       []          []
# 65334  {'username': 'simran', 'displayname': 'Simran ...       []          []
# 41084  {'username': 'MeghUpdates', 'displayname': 'Me...       []          []
# 59355  {'username': 'cjwerleman', 'displayname': 'CJ ...       []          []
# 44654  {'username': 'J4SHANBAINS', 'displayname': 'Ja...       []          []
# 64307  {'username': 'RaviSinghKA', 'displayname': 'ra...       []          []
# 29582  {'username': 'saahilmenghani', 'displayname': ...       []          []
# 52660  {'username': 'TanDhesi', 'displayname': 'Tanma...       []          []
#
#        replyCount  retweetCount  ...  quoteCount       conversationId  lang  \
# 95467         708          6592  ...         255  1364148079117615105    en
# 55083         439          2837  ...         299  1368994520004780034    en
# 29485         339          2797  ...          93  1372591661490917377    en
# 65334          75          2393  ...         155  1367681014739460098    en
# 41084         220          2074  ...          74  1371017710700617729    en
# 59355         174          2025  ...         125  1368335535786184705    en
# 44654         112          1906  ...         136  1370526101739511810    en
# 64307          70          1789  ...         126  1367752937808818177    en
# 29582          68          1647  ...          70  1372570866404397059    en
# 52660         203          1610  ...         122  1369299734448508928    en
#
#                                                   source  \
# 95467  <a href="http://twitter.com/download/iphone" r...
# 55083  <a href="https://studio.twitter.com" rel="nofo...
# 29485  <a href="http://twitter.com/download/iphone" r...
# 65334  <a href="http://twitter.com/download/iphone" r...
# 41084  <a href="http://twitter.com/download/android" ...
# 59355  <a href="http://twitter.com/download/iphone" r...
# 44654  <a href="http://twitter.com/download/iphone" r...
# 64307  <a href="http://twitter.com/download/iphone" r...
# 29582  <a href="http://twitter.com/download/android" ...
# 52660  <a href="https://mobile.twitter.com" rel="nofo...
#
#                                  sourceUrl           sourceLabel  \
# 95467   http://twitter.com/download/iphone    Twitter for iPhone
# 55083           https://studio.twitter.com  Twitter Media Studio
# 29485   http://twitter.com/download/iphone    Twitter for iPhone
# 65334   http://twitter.com/download/iphone    Twitter for iPhone
# 41084  http://twitter.com/download/android   Twitter for Android
# 59355   http://twitter.com/download/iphone    Twitter for iPhone
# 44654   http://twitter.com/download/iphone    Twitter for iPhone
# 64307   http://twitter.com/download/iphone    Twitter for iPhone
# 29582  http://twitter.com/download/android   Twitter for Android
# 52660           https://mobile.twitter.com       Twitter Web App
#
#                                                    media retweetedTweet  \
# 95467  [{'previewUrl': 'https://pbs.twimg.com/media/E...            NaN
# 55083  [{'thumbnailUrl': 'https://pbs.twimg.com/ampli...            NaN
# 29485                                               None            NaN
# 65334  [{'previewUrl': 'https://pbs.twimg.com/media/E...            NaN
# 41084                                               None            NaN
# 59355  [{'thumbnailUrl': 'https://pbs.twimg.com/ext_t...            NaN
# 44654  [{'thumbnailUrl': 'https://pbs.twimg.com/ext_t...            NaN
# 64307  [{'previewUrl': 'https://pbs.twimg.com/media/E...            NaN
# 29582                                               None            NaN
# 52660  [{'thumbnailUrl': 'https://pbs.twimg.com/ext_t...            NaN
#
#        quotedTweet                                     mentionedUsers
# 95467         None                                               None
# 55083         None                                               None
# 29485         None                                               None
# 65334         None                                               None
# 41084         None                                               None
# 59355         None                                               None
# 44654         None                                               None
# 64307         None  [{'username': 'narendramodi', 'displayname': '...
# 29582         None                                               None
# 52660         None                                               None
#
# [10 rows x 21 columns]

# %%
def getUserName(row):
    return row["user"]['username']
def getTopTenUsers():
    topTen = raw_tweets
    topTen['userName'] = topTen.apply(lambda row:getUserName(row), axis=1)
    topTen = topTen.groupby(['userName']).sum()
    topTen = topTen.sort_values(by="retweetCount", ascending=False)
    return topTen
topTen = getTopTenUsers()
topTen.head(10)
# Out:
#                            id  replyCount  retweetCount  likeCount  \
# userName
# NavJammu         1.223340e+21      2218.0       65550.0    50849.0
# amaanbali        3.531917e+20      3838.0       43409.0   147694.0
# saahilmenghani   1.081380e+20      1495.0       32293.0    92272.0
# Drkhinda2        4.388046e+20       415.0       20117.0    17381.0
# Iamjazzie96      1.796427e+21      1202.0       14023.0    12144.0
# Bkuektaugrahan   1.917289e+20       834.0       13808.0    31852.0
# RaviSinghKA      2.878350e+19      1734.0       10814.0    44971.0
# ninabhullar1     6.296246e+20       360.0       10446.0     9799.0
# HarteerathSingh  2.342046e+20      1067.0       10437.0    37729.0
# with_kaur        1.746832e+21       506.0        9241.0     8124.0
#
#                  quoteCount  conversationId  retweetedTweet
# userName
# NavJammu             4121.0    1.223334e+21             0.0
# amaanbali            3355.0    3.531917e+20             0.0
# saahilmenghani       1521.0    1.081379e+20             0.0
# Drkhinda2            1333.0    4.388000e+20             0.0
# Iamjazzie96           781.0    1.796414e+21             0.0
# Bkuektaugrahan        905.0    1.917289e+20             0.0
# RaviSinghKA           825.0    2.878350e+19             0.0
# ninabhullar1          655.0    6.296242e+20             0.0
# HarteerathSingh       878.0    2.342042e+20             0.0
# with_kaur             298.0    1.746788e+21             0.0
